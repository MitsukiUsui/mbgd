# %%
from Bio import SeqIO
import pandas as pd

# %%
filepath="geneseq.fasta"
for seqRecord in SeqIO.parse(filepath, "fasta"):
    print(len(seqRecord))
# Out:
# 1617
# 1674

# %%
filepath="proteinseq.fasta"
for seqRecord in SeqIO.parse(filepath, "fasta"):
    print(len(seqRecord))
# Out:
# 538
# 557

# %%
filepath="../../blastn/result/eci_yieC.tab"
df=pd.read_csv(filepath,delimiter='\t',header=None)
df
# Out:
#                      0                   1        2     3    4   5    6   \
# 0       ecp:ECP_RS07730  eci:chromosome-1-1  100.000   297    0   0   16
# 1     eci:UTI89_RS08485  eci:chromosome-1-1  100.000  1674    0   0    1
# 2        ecz:ECS88_1610  eci:chromosome-1-1  100.000  1674    0   0    1
# 3     eab:ECABU_RS08925  eci:chromosome-1-1   99.701  1674    5   0    1
# 4       elc:I14_RS08850  eci:chromosome-1-1   99.701  1674    5   0    1
# 5      eln:NRG857_07570  eci:chromosome-1-1   99.701  1674    5   0    1
# 6      eln:NRG857_07570  eci:chromosome-1-1   70.690   464  115  19  389
# 7      eoc:CE10_RS09205  eci:chromosome-1-1   97.431  1674   43   0    1
# 8      eoc:CE10_RS09205  eci:chromosome-1-1   71.053   418  106  12  389
# 9   ecm:ECSMS35_RS08280  eci:chromosome-1-1   97.192  1674   47   0    1
# 10  ecm:ECSMS35_RS08280  eci:chromosome-1-1   71.053   418  106  12  389
#
#       7        8        9              10      11
# 0    312  1678738  1678442  5.490000e-157   549.0
# 1   1674  1680115  1678442   0.000000e+00  3092.0
# 2   1674  1680115  1678442   0.000000e+00  3092.0
# 3   1674  1680115  1678442   0.000000e+00  3064.0
# 4   1674  1680115  1678442   0.000000e+00  3064.0
# 5   1674  1680115  1678442   0.000000e+00  3064.0
# 6    840  4162856  4162402   3.800000e-16    84.2
# 7   1674  1680115  1678442   0.000000e+00  2854.0
# 8    797  4162856  4162445   2.940000e-17    87.9
# 9   1674  1680115  1678442   0.000000e+00  2832.0
# 10   797  4162856  4162445   2.940000e-17    87.9
